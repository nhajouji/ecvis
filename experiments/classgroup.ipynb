# %%
import os
os.chdir('../')

# %%
from ecc.modulargroup import *
from ecc.utils import gcd_list, discfac,primesBetween

# %%
d_to_clgr = {}
for d in range(-20,-1000,-1):
    if d % 4 < 2:
        qfs = get_qfs_strict(d)
        if len(qfs)>5:
            d_to_clgr[d]=QFClassGroup(d)
ds_list = [d for d in d_to_clgr]

# %%
d_to_clgr_orders = {d:d_to_clgr[d].qf_orders() for d in d_to_clgr}
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 d_to_clgr_orders = {d:d_to_clgr[d].qf_orders() for d in d_to_clgr}
#
# File ~/Documents/GitHub/ecvis/ecc/modulargroup.py:381, in QFClassGroup.qf_orders(self)
#     379 n = len(qfs)
#     380 dns = divisors(n)
# --> 381 return {qf:min([n0 for n0 in dns if self.qf_power(qf,n0)==qf0]) for qf in qfs}
#
# ValueError: min() iterable argument is empty

# %%
d
# Out:
# -999
